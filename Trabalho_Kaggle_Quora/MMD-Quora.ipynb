# %% [markdown]
# ### Trabalho MMD

# %% [markdown]
# #### Students: Joao Marcos and Antonio Sombra

# %%
#https://www.kaggle.com/c/word2vec-nlp-tutorial/details/part-1-for-beginners-bag-of-words

# %% [markdown]
# ### Reading packages

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
#strings
import string
import nltk
import nltk.data
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer

#Extras
import os
import sys
import time
import re
import pickle
import logging

#basic
import numpy as np
import pandas as pd
import xgboost as xgb
import string


# Visualisation
import pylab
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from matplotlib.font_manager import FontProperties
import seaborn as sns

# Modelling Helpers
from sklearn.preprocessing import Imputer , Normalizer , scale
from sklearn.cross_validation import train_test_split , StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.cluster import KMeans
from sklearn.metrics import roc_auc_score as AUC
import gensim
from gensim import corpora
from gensim import models
from gensim import similarities
from gensim.models import Word2Vec

from bs4 import BeautifulSoup

# %matplotlib inline
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# #### Load data

# %%
'''datapath = "/Dados/Kaggle/"
word2vec= "/Dados/Word2vec"
train = pd.read_csv(os.path.join(datapath, 'train.csv'))
'''

# %%
data_train = pd.read_csv('train.csv')
#data_test = pd.read_csv('../input/test.csv')
#train = pd.read_csv(os.path.join(datapath, 'train.csv'))
data_train.sample(3)
# Out:
#             id    qid1    qid2  \
# 29098    29098   53878    1397
# 303180  303180  426286  364791
# 376397  376397  507527  507528
#
#                                                 question1  \
# 29098   How do you train a Jack Russell/West Highland ...
# 303180         What are the best slide guitar solos ever?
# 376397                How can you unlock a Compaq laptop?
#
#                                                 question2  is_duplicate
# 29098   How do you train a white Pitbull with brown sp...             1
# 303180       What is the worst guitar solo in rock music?             0
# 376397                 How do you unlock a Compaq laptop?             1

# %%
data_train.info()
#data_train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
# id              404290 non-null int64
# qid1            404290 non-null int64
# qid2            404290 non-null int64
# question1       404290 non-null object
# question2       404288 non-null object
# is_duplicate    404290 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
data_train.columns
type(data_train)
# Out:
# pandas.core.frame.DataFrame

# %%
data_train2=data_train.dropna(0)
data_train2.info()
type(data_train2)
#axis : {0 or 'index', 1 or 'columns'}, or tuple/list thereof
   # Pass tuple or list to drop on multiple axes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 404288 entries, 0 to 404289
# Data columns (total 6 columns):
# id              404288 non-null int64
# qid1            404288 non-null int64
# qid2            404288 non-null int64
# question1       404288 non-null object
# question2       404288 non-null object
# is_duplicate    404288 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 21.6+ MB
# pandas.core.frame.DataFrame

# %%
# Choosing the list of stopwords
mystopwords = nltk.corpus.stopwords.words('english')
list_of_words= ['where','what','when','why','between','who','how','which']
for item in list_of_words:
        mystopwords.remove(item)

# %%
#Stemmers remove morphological affixes from words, leaving only the word stem.
#http://www.nltk.org/howto/stem.html
#The 'english' stemmer is better than the original 'porter' stemmer.
#example; stemmer.stem('likely', 'bites') - like, bite 
#http://www.nltk.org/api/nltk.tokenize.html
#A tokenizer that divides a string into substrings by splitting on the specified string (defined in subclasses).
#word_tokenize("It's only a test")- ['It', "'s", 'only', 'a', 'test']

# %%
class Text_Cleaning_Utilities(object):
    """Tools for processing text into segments for further learning"""

    @staticmethod
    def text_to_wordlist(text, 
                         remove_stopwords=False,
                         remove_non_letters=False, 
                         steeming=False):
        '''Split a text into a list of words'''
        #text = text.replace('-\n','')
        text = text.lower()
        if remove_non_letters:
            text = re.sub("[^-A-Za-z0-9_]", " ", text)
        list_words = word_tokenize(text)
        list_words = [w.strip(string.punctuation) for w in list_words if w not in string.punctuation]
        list_words = [w for w in list_words if len(w) > 1]
        if remove_stopwords:
            stops = set(mystopwords)
            list_words = [w for w in list_words if w not in stops]
        if steeming:
            stemmer = SnowballStemmer("english")
            list_words = [stemmer.stem(item) for item in list_words]
        return list_words
    
    @staticmethod
    def df_to_list_of_texts(dataframe, column, 
                            remove_stopwords=False,
                            remove_non_letters=False, 
                            steeming=False):
        clean_texts = []
        for txt_id in range(len(dataframe[column])):
            clean_texts.append(' '.join(Text_Cleaning_Utilities.text_to_wordlist(dataframe[column][txt_id],
                                                                                 remove_stopwords=remove_stopwords,
                                                                                 remove_non_letters=remove_non_letters,
                                                                                 steeming=steeming)))
            
        return clean_texts

    @staticmethod
    def df_to_list_of_tokens(dataframe, column, 
                             remove_stopwords=False, 
                             remove_non_letters=False, 
                             steeming=False):
        clean_texts = []
        for txt_id in range(len(dataframe[column])):
            clean_texts.append(Text_Cleaning_Utilities.text_to_wordlist(dataframe[column][txt_id],
                                                                        remove_stopwords=remove_stopwords,
                                                                        remove_non_letters=remove_non_letters,
                                                                        steeming=steeming))
            
        return clean_texts

# %%
db_clear_q1=Text_Cleaning_Utilities.df_to_list_of_texts(data_train,'question1',remove_stopwords=True)

# %%
db_clear_q1
# Out:
# ['what step step guide invest share market india',
#  'what story kohinoor koh-i-noor diamond',
#  'how increase speed internet connection using vpn',
#  'why mentally lonely how solve',
#  'which one dissolve water quikly sugar salt methane carbon di oxide',
#  'astrology capricorn sun cap moon cap rising what say',
#  'buy tiago',
#  'how good geologist',
#  'when use instead',
#  'motorola company hack charter motorolla dcx3400',
#  'method find separation slits using fresnel biprism',
#  'how read find youtube comments',
#  'what make physics easy learn',
#  'what first sexual experience like',
#  'what laws change status student visa green card us how compare immigration laws canada',
#  'what would trump presidency mean current international master’s students f1 visa',
#  'what manipulation mean',
#  'why girls want friends guy reject',
#  'why many quora users posting questions readily answered google',
#  'which best digital marketing institution banglore',
#  'why rockets look white',
#  'what causing someone jealous',
#  'what questions ask quora',
#  'how much 30 kv hp',
#  'what mean every time look clock numbers',
#  'what tips making job interview process medicines',
#  'what web application',
#  'society place much importance sports',
#  'what best way make money online',
#  'how prepare ca final law',
#  'what one thing would like better',
#  'what special cares someone nose gets stuffy night',
#  'what game thrones villain would likely give mercy',
#  'united states government still blacklist employment etc united states citizens political views',
#  'what best travel website spain',
#  'why people think obama try take guns away',
#  '19-year-old how improve skills what become entrepreneur next years',
#  'when girlfriend asks boyfriend why choose what makes want what one reply',
#  'how prepare upsc',
#  'what stall speed aoa f-14 wings fully swept back',
#  'why slavs squat',
#  'when expect cognizant confirmation mail',
#  'make 50,000 month day trading',
#  'good kid rebel worth long run',
#  'what universities rexnord recruit new grads what majors looking',
#  'what quickest way increase instagram followers',
#  'how darth vader fought darth maul star wars legends',
#  'what stages breaking between couple mean what happens breaking emotionally whether male female',
#  'what examples products make crude oil',
#  'how make friends',
#  'career launcher good rbi grade preparation',
#  'blu ray play regular dvd player how',
#  'nd always sad',
#  'what best/most memorable thing ever eaten why',
#  'how gst affects cas tax officers',
#  'how difficult get rsi',
#  'who israil friend',
#  'what good rap songs dance',
#  "suddenly logged gmail ca n't remember gmail password realized recovery email longer alive what",
#  'what best ways learn french',
#  'how download content kickass torrent without registration',
#  'normal dark ring around iris eye',
#  'how new harry potter book harry potter cursed child',
#  'why always get depressed',
#  'where find european family office database',
#  'what java programming how learn java programming language',
#  'what best book ever made',
#  'ever store energy produced lightning',
#  'what review performance testing',
#  'what cost much privacy germany come what else lost gain much privacy',
#  'what types immunity',
#  'what narcissistic personality disorder',
#  'how speak english fluently',
#  'how helpful quickbooks auto data recovery support phone number recover corrupted data files',
#  'who richest gambler time how reach level',
#  'fire bullet backward aircraft going faster bullet bullet going backwards',
#  'how prevent breast cancer',
#  'how log gmail account friend phone',
#  'how make money internet',
#  'what purpose life',
#  'when bjp government strip muslims christians indian citizenship put boats like rohingya burma',
#  'what right etiquette wishing jehovah witness happy birthday',
#  'someone wants open commercial fm radio station city india how much cost what procedure',
#  'why swiss despise asians',
#  'what high salary income jobs field biotechnology',
#  'how increase height 21 also',
#  'what major effects cambodia earthquake how effects compare kamchatca earthquakes 1952',
#  'what difference between sincerity fairness',
#  'which best gaming laptop 60k inr',
#  'what review next warrior proving grounds part',
#  'what best reference book physics class 11th',
#  'national institute technology kurukshetra how social life nitk surathkal',
#  'what best romantic movies english',
#  'what causes nightmare',
#  'what abstract expressionism painting',
#  'how 3d printing work',
#  'what like attend caltech jeremy ehrhardt',
#  'why harry become horcrux',
#  'what best associate product manager apm programs someone early 20s join learn product management rewarding career company',
#  'why number skype 1-855-425-3768 always busy',
#  'really war between india pakistan uri attack what effects',
#  'ronald reagan mannerism speech',
#  'what war strategies union confederates civil war',
#  'which best fiction novel 2016',
#  'recover email forgot password',
#  'recent demonetisation results higher gdp how much',
#  'ever heard travel hacking',
#  'what difference between love pity',
#  'how competitive hiring process republic bank',
#  'how google helps spam ranking adjustment search results',
#  'where watch gonulcelen english subtitles',
#  'usa powerful country world',
#  'how obtain instant ulcer pain relief',
#  'what think china food',
#  'what taking advantage someone mean',
#  'why cry when happy when sad',
#  'why girls like stick tongues when taking pictures',
#  'find ending novel 1984 depressing',
#  "what mind-blowing computer tools exist people n't know",
#  'toothbrush wet dry applying toothpaste',
#  'why question marked needing imrovement',
#  'what difference between neutral state buffer state',
#  'what mineral holds highest electrical charge',
#  'what greatest mystery universe',
#  'what alternative machine learning',
#  'why china block sanctions un jaish-e-mohammad jem chief masood azhar',
#  'what mean future budget',
#  'excessive amounts vitamin cause miscarriage',
#  'what like work asahi india glass what pay scale one two years',
#  'how access torbox india',
#  'what yakshini mantras',
#  'six party talks successful',
#  'how register domain site email',
#  'normal older men attracted young women',
#  'what strongest structure strongest shape compression',
#  'who rohingya muslims',
#  'matter whether humans selfish evil',
#  'exocytosis endocytosis examples active passive transport',
#  'how get hair bald head',
#  'what ideal life retirement',
#  'what stance pakistan',
#  'what good websites escorts',
#  'which one better polo diesel grand i10 petrol',
#  'black hole mass',
#  'morgan freeman correct when says way stop racism stop talking',
#  'fab currently offer new employees stock options rsus',
#  'how would review site waveclues',
#  'how many ways distribute 10 identical looking pencils students student gets least one pencil',
#  'how much would cost hire jerry seinfeld 1-2 hours',
#  'days late rabies vaccine possible non-bite exposure',
#  'how many years britain ruled india',
#  'how stop afraid working',
#  'why red keep keys oitnb',
#  'what age someone lose virginity',
#  'how forgetful',
#  'could snoke secretly darth maul',
#  'monetize youtube videos upload copyright content chances google may block account',
#  'would switch canon 6d leica d-lux 109',
#  'what quora website look like members quora moderation',
#  'why nobody answer questions quora',
#  'what funniest joke know',
#  'got job offer chelmsford-essex london £3764 pm pay-after tax deduction pls advice tentative monthly expenses couple saving possible',
#  'what stereotypes united kingdom',
#  'how use twitter business source',
#  'how transfer money skrill paypal account',
#  'which best earphone deep bass 1000',
#  'government employees eligible sukanya samrudi yojana',
#  'which correct looking forward speak look forward speak',
#  'which best engineering fields',
#  'how make life suit stop life abusing mentally emotionally',
#  'what difference between gross salary ctc',
#  'which prospering towns kerala',
#  'what best way gain confidence',
#  'anyone see relation between greek gods hindu gods',
#  'how switch apple music spotify',
#  'which best fixed income fund',
#  'what like live cologne',
#  'between robert de niro al pacino who successful',
#  'why people prefer small families',
#  'animals kiss',
#  'how get deleted instagram chats',
#  'how stop addicted love',
#  'what hired two private eyes ordered follow',
#  'how find startup accelerator',
#  'how check wifi history access android phones',
#  'what significance battle somme how battle compare contrast battle rostov',
#  'what creative college admissions essay read',
#  'what would happen cover one eyes eye patch one year take patch',
#  'possible pursue many different things life',
#  'ben affleck shine christian bale batman',
#  'which business good start hyderabad',
#  'how stop possessive',
#  'who wife lord krishna',
#  'what best combination courses take along ca enhance career',
#  'how take screenshot mac laptop',
#  'what work executive recruiter like',
#  'which psychological need collecting fulfill',
#  'what must watch tv shows die',
#  'how become fluent chinese',
#  'what effects demonitization 500 1000 rupees notes real estate sector',
#  'what easiest way become billionaire',
#  'people who willing give free lectures conduct free workshop india colleges',
#  'what best way start learning robotics',
#  'why people hate hillary clinton',
#  'why women who periods regarded unclean prevented taking actived part rituals hinduism',
#  'atheism lack belief gods what term belief god',
#  'what like jack dorsey',
#  'what best quotes/lessons assassin creed series',
#  'inkjet printers use color ink when printing black white documents why',
#  'why creativity important',
#  'hillary clinton could continue presidential campaign how would democratic party choose new candidate',
#  "how headphones work antenna play fm radio channels mobile phones why mobile companies n't install inbuilt antenna phones able play fm without headphones",
#  'what best career growth technologies automation engineers apart automation tools',
#  'what disadvantages listing company nse',
#  'how many derivatives object position respect time continuous',
#  'neutron star made',
#  'got 3.8 gpa enough get top universities like harvard',
#  'what profitable way trade binary options',
#  'how utilize free time avoid depression',
#  'how learn computer security',
#  'how earn quora',
#  'what puk code',
#  'how find job japan',
#  'what examples sentences using word hysteria',
#  'another billion dollar lottery jackpot',
#  'how scary drive road hana given turns',
#  'how create new shell new terminal using programming linux terminal',
#  'cognition affect perception',
#  'how tqwl different ckwl tatkal waiting list',
#  'how make world better place live future generations',
#  'how many champions league legends',
#  'drinking liters water day unhealthy',
#  'where water great lakes come how lakes wildlife compare lake prespa',
#  'porn stars watch porn',
#  'trump supporters how feel way walking back promises',
#  'why worried others opinions',
#  'how potty train months pitbull',
#  'jump rope five minutes how many calories use',
#  'which online test series best gate 2017 cs stream',
#  'what best material understanding algorithmic analysis newbie',
#  'what temperament bullmastiff/husky mix',
#  "balls weigh different weight n't know heavier lighter how find odd ball weighs",
#  'play raisin sun why walter ad beneatha argue',
#  'what signs ultra smart person playing dumb',
#  'dark energy created expansion infinite created',
#  'how get book published',
#  'who disrupting bloomberg',
#  'why flash run fast',
#  'what best way invest 500 legally get tangible profits relatively short period time say months',
#  'how implementation gst bill impact lives common people',
#  'how recover gmail password',
#  'how accurately mental illness diagnosed',
#  'knee pain 20 year old girl normal',
#  'what qualities good leader',
#  'what difference between bay gulf straits',
#  'modi win 2019',
#  'how open dmart store india franchise',
#  'what best youtube channels learn medicine',
#  'swami vivekananda ever eat non-veg egg journey around world',
#  'what happen cancel tqwl tickets charting done',
#  'what exactly common core initiative/standards what pros cons',
#  'how choose journal publish paper',
#  'what new year resolutions 2017',
#  'what bad dream',
#  'why slavs squat',
#  'how many marks score aiims rank 151',
#  'operating room when two surgeons equal experience disagree surgical procedure how tie broken',
#  'how many months take gain knowledge developing android apps scratch',
#  'how love body guy',
#  'what rights prisoner',
#  'how get free gems clash clans',
#  "why n't apps like word lens",
#  'ex-girlfriend suffering malaria deep urge visiting placements idea how what',
#  'what best way get traffic website',
#  'how feel when someone upvotes answer quora',
#  'what best films tv shows feature strong female protagonists',
#  'how far would go love wait one love ir move',
#  'how people die',
#  'why clothes made polyester instead cotton',
#  'what bone marrow',
#  'slave name reddice',
#  'how long take dead body float surface drowning',
#  "how get friend n't talked years still miss",
#  'when travelling new region better immerse 1–2 cities see many cities cram',
#  'how make money online free cost',
#  'where buy best quality customized cupcakes gold coast',
#  'how successful odd even plan',
#  'war between india pakistan who win',
#  'how deal fear dying',
#  'what would estimated cost repairing cracked screen iphone',
#  'what interesting products innovations mcdonald coming 2016',
#  'end universe universe infinite',
#  'what cpagrip.com',
#  'how much funds raise',
#  'what anna hazare think pm modi',
#  'what effect banning 500 1000 notes stock markets india',
#  'how concentric contractions differ eccentric contractions',
#  'why puppet used yoda episode suck bad',
#  'what online platforms post ads beer money opportunity',
#  'what meaning life',
#  'how start small business effectively',
#  'how acquire positive morality',
#  'need friends',
#  'exist',
#  'which best hollywood thriller movies',
#  'repeat 2nd year college find new college year course',
#  'how petrol diesel pumped filling station using motor without igniting fire',
#  'what job possibilities exist bachelors homeland security',
#  'which best books understand calculus',
#  'why how break her/him',
#  'use jio sim iphone 5s',
#  'what unwritten rules usa',
#  'what best answer what two years gap job interview',
#  'what best songs low voices',
#  'anyone predict birth chart',
#  'when birth trigonometric functions',
#  "what saying mean n't trust everything see even salt looks like sugar",
#  'what countries prevent war',
#  'how become billionaire',
#  'why learn web design',
#  'what best on-line calender/scheduling/booking system something allows show availability customers request meet when accept request appointment pops calendars reminders automated',
#  'how indian gdp affected banning 500 1000 rupees notes',
#  'why understanding death philosophical',
#  'why dogs considered omnivores',
#  'what like cheated upon relationship',
#  'how know someone blocked texts',
#  'what interesting foods eaten country',
#  'what like private banker',
#  'what journalism',
#  'how one increase concentration',
#  "how see sent invitations linkedin n't pending invitations",
#  'what pros cons german shepherd dog',
#  'what difference between deism agnosticism',
#  'why male porn stars masturbate ejaculate',
#  'how much cgpa require get admission mtech cse iit madras',
#  'biological reason people cry when emotional',
#  'what facts earth crust',
#  'why isro use friction stir welding technology',
#  'wish simulate fake location app running ios device how fake gps location ios without jailbreaking non-coder',
#  'what would best way quit smoking',
#  'which best programing language tcs',
#  'earthquake resistant homes',
#  'kristen stewart bad actress why why',
#  "why japanese guys try look feminine n't girls find gross",
#  'what five popular sugar daddy websites',
#  'what vtu 1st sem exam time table 2016 dec',
#  'what best phone buy 15k',
#  'how start business',
#  'what best near-death experience ever',
#  'why keep getting fleas dogs',
#  'what year letter come',
#  'harvard college courses what general shopping advice turkish classes',
#  'how send message one android phone another android phone bluetooth',
#  'what important books ever written',
#  'what universities sigma designs recruit new grads what majors looking',
#  'm.phil india masters uk psychology',
#  'what universities powell industries recruit new grads what majors looking',
#  'what best movie posters come across',
#  'what examples deuteromycota how formed',
#  'how racist racist',
#  'differences between however nevertheless',
#  'canada geese really canadian',
#  'how find zeros polynomial function math dfrac 3x math',
#  'how edit devices google play account',
#  'how become good speaker',
#  'how write letter mr narendra modi',
#  'who electable general presidential election donald trump ted cruz',
#  'why name bastards snow',
#  'what think bermuda triangle',
#  'mexican girls like black guys',
#  'lived tiny house',
#  'what boy/girl called when he/she 1-6 years old 6-11years old 11-14 years old 14-18 years old',
#  'debeak cockerels months old',
#  'what someone overcome anxiety',
#  'how avoid whey yogurt',
#  'im love bisexual best friend who also guy girlfriend want tell how move',
#  'what best university germany ms',
#  'how maintain peace mind',
#  'which car good build quality india',
#  'why massaging one temples soothe migraine headache',
#  'which one better among kmc manipal kmc mangalore',
#  'why bestfriend still ignoring',
#  'what sensors available acer liquid z630s android smart phone using cpu-z app',
#  'how keep motivation learn language',
#  'what top assessment companies india',
#  'what mean emoticon',
#  'pinkish discharge normal early pregnancy what causes',
#  'what best ways properly finger',
#  'how scientists work',
#  'how many sponsored candidates shortlisted cmc vellore',
#  'what different between chinese wedding ceremony western wedding ceremony',
#  'what condition tourism pakistan',
#  'what different between offshore onshore funds',
#  'why one hate shahrukh khan',
#  'what best self-help books ever read',
#  'evernote useful',
#  'title continuation gift magi',
#  'what good song lyric prank best friend',
#  'argued gf made friends person hit said control freak wants freedom what',
#  'how pass drug test methamphetamine',
#  'how could start open source development',
#  'why dreams look real',
#  'cricket players really drink tea tea break',
#  'how get entry mit',
#  'fetus breathe when inside womb',
#  'what movies incest scenes',
#  "what signs guy feelings crush n't want show hides",
#  'according international federation robotics how many robots existed 2012',
#  'why oberon mad titania midsummer night dream',
#  'regret divorce',
#  'how much dna change time clone 70 years clone hair color',
#  'right tell girl feelings',
#  'donald trump taking cocaine howard dean suggests',
#  'true order part elite rich successful join secret organisation otherwise chance',
#  'which financially beneficial firm teaching architecture college',
#  'how see comedy nights kapil live show',
#  'why sandeep maheshwari quora',
#  'what biggest monster monster hunter',
#  'how convince people stop blaspheming holy spirit',
#  "why ca n't stop watching porn",
#  'how start trusting one',
#  'what bucket list',
#  'how first come across porn',
#  'which car services available normal il how good compared taxis relative',
#  'why can’t charged molecules pass lipid cell membrane',
#  'how feel spouse renowned porn star',
#  'what best hostel booking affiliate program',
#  'how drive brooklyn staten island described how cities tourist attractions compare queens',
#  'what eat every day healthy',
#  'how make free calls family members airtel andhra pradesh',
#  'what would hillary clinton election',
#  'use vicks vapor rub stuffy nose',
#  'how start prepare ugc net english literature latest syllabus',
#  'how early europeans get protein columbian exchange',
#  'what best forum graphic designers',
#  'alex jones satirical show',
#  "learn angularjs 1.5 instead angularjs n't know typescript",
#  "why ca n't fall asleep days",
#  'which marvel movies included stan lee cameos',
#  'what views modi governments decision demonetize 500 1000 rupee notes how affect economy',
#  'what 10/6 label mad hatter hat mean',
#  'who wrote kars kids jingle',
#  'why saltwater taffy candy imported greece',
#  'what minimum requirements enter mit',
#  'how answer question quora',
#  'israel vs iran who would win',
#  'when late learn piano',
#  'what natural numbers',
#  'one plus 3t 4g volte enabled phone',
#  'how enter new email id which access recover facebook id',
#  'how travel faster light',
#  'what like firefighter',
#  'what factors causes data inconsistency distributed platform/application',
#  'what differences between pocso sexual offenses ipc',
#  'what alternative word',
#  'what considered illegal screen nba',
#  'nothing excites anymore how regain excitement',
#  'what life lessons batman teaches us',
#  'how stop criminal attempt kidnap escape unharmed',
#  'how sell amazon',
#  'daniel ek when expect spotify india',
#  'what top 10 books one read early 20s',
#  'which book start gate preparation',
#  'what phrase who love abides death exactly mean',
#  'what similar 4shared',
#  'get high someone touches weed shake hand eat something hand',
#  'considering current trend information technology what future print media',
#  'what best recipe chicken pizza',
#  'what good places learn mountaineering india',
#  'new table tennis balls damage rubbers',
#  "new xbox one ca n't connect internet setup solutions",
#  'wrong content life',
#  'gravity theory',
#  'how could become fighter pilot when less required eyesight',
#  'operation executive salary infosys',
#  'cavemen scientifically tested',
#  'climate change reversed',
#  'how ask crush number',
#  'why believe gravitation force exist',
#  'mahabharata really happen',
#  'congress stop presidents starting major war',
#  'safe lose 25 pounds month',
#  'what cute shounen ai series',
#  'why police lights red blue',
#  'how post question marked needing improvement',
#  'who owns nature',
#  'how install obb/data file android',
#  'what garbage value why get garbage value',
#  'how prepare software interviews',
#  'rahul gandhi chance become next pm india modi',
#  'noon 12 12 pm',
#  'what difference between comet asteroid',
#  'chocolate milk good',
#  'how study',
#  'which country best higher education work',
#  'what painting image',
#  'which major highways california how compared major highways tennessee',
#  'what beyond universe',
#  'growing hair physical chemical change',
#  'what difference between culture history',
#  'what mean when guy says like',
#  'what makes programmer good',
#  'what likely cause world war iii',
#  'civil war likely us presidential election',
#  'which european country best asylum seekers',
#  'where how crop circles get generated',
#  'baking soda help pass urine test',
#  'what zika virus how transmitted',
#  'what best way learn algebra',
#  'how feel retake class college',
#  'google display network require site seo on-page off-page optimized first proceed gdn possible',
#  'how hard fake appearing spiritual christian community',
#  'what actinomorphic flower',
#  'what best place sex',
#  'people anemia die younger',
#  'how feel new macbook pro late 2016',
#  'covering head sleeping cause brain damage',
#  'what major differences between chinese culture western cultures',
#  'what scraping techniques',
#  '29y old diabetic type recently sugar level increased 150 fasting exercise eat whole grains why happening',
#  'healthy eat egg whites every day',
#  'what words rank highest dictionary.com difficulty index',
#  "why ca n't feel remorse empathy",
#  'how many minutes cardio day',
#  'why dog biting',
#  'how treat severe foot sprain',
#  'how severe crick neck treated',
#  'what best places recommend foreigners visit nepal',
#  'who activate dlc skyrim laptop ive got working computer command lines laptop use',
#  'how prepare hsbc glt placement tests',
#  'indian writers/authors ever use pen name',
#  'how register institute providing training various programming languages vocational courses exempt service tax',
#  'how imminent world war iii',
#  'how write song',
#  'what could narendra modi next move demonetization',
#  "want share share n't got what",
#  "what interesting fact know n't n't",
#  'what problem controlled fusion',
#  'where find 3ds emulator android',
#  'want start clothes boutique india where buy cheap wholesale clothes',
#  'how become true computer science engineer',
#  'necessary unlock bootloader rooting android phones',
#  'what bss engineer',
#  'why get punished quora moderators when put israel judaism negative light',
#  'what lucid dreams',
#  'what feel like beautiful',
#  'possible ca 12th science',
#  'how hack someones whatsapp account',
#  'what like study math ucla',
#  'what best lesson life',
#  'what interesting mobile apps',
#  'how trump presidency affect indian students who planning phd us',
#  'what various batman movies series order',
#  'what best daily life hacks one use make life easy',
#  'how much weight lose eating week',
#  'what favourite anime character why',
#  'how atm machines work internally',
#  'how many mechanical engineers graduate india per year',
#  'how start successful private equity firm',
#  'what underrated date activities',
#  'what common facts every mechanical engineer know',
#  'what medium budget visit best places kerala three members 2-3 days',
#  'why quora digest filled questions google iq china',
#  'how would destroy world',
#  'how earn money youtube',
#  'what differences between particles molecules',
#  'facebook how add mutual friends',
#  'what russian president vladmir putin like person closest friends family',
#  'how start writing',
#  'time started big bang happening how could big bang start time big bang start',
#  'how feel relationship single how life changes when relationship',
#  'how start civil service exam preparation scratch',
#  'what non-invasive blood glucose monitoring systems abroad',
#  'what difference pleasure between masturbation sex',
#  'what things change stay mean',
#  'how start solar energy business egypt',
#  'pc specs gb ddr2 ram intel core duo 3.5 ghz nvidia geforce gt 610 3gb ddr3 run assassin creed syndicate gta',
#  'psychic abilities',
#  'how manage time studies',
#  'what academic calendar xlri',
#  'what take urjit patel new rbi governor',
#  'why want president',
#  'why india friendly relations neighbouring countries',
#  'trump voters care reneged campaign promises',
#  'learn sleeping how',
#  'play asian playstation games european playstation',
#  'how stop addicted porn',
#  'why british engineering manufacturing skills decline dramatically 60s 70s 80s especially when compared germany',
#  'how work machine learning researchers graduation',
#  'what future ios developers',
#  'what meaning life whats purpose earth',
#  'how boyfriend',
#  'how time travel possible',
#  'how one get fuller face',
#  'late age 25 thinking start career photography',
#  'what’s best time sex',
#  'weld steel aluminum together',
#  'which youtube video highest like/dislike ratio',
#  'what solution kashmir issue',
#  'dug hole earth came side what would happen',
#  'create free energy',
#  'what web design',
#  'what funniest highbrow joke ever heard',
#  'how find phenotypic ratio',
#  'why saturn benefit house sits slowly',
#  'who academically qualified bollywood celebrity',
#  'difference quality between wired wireless headphones why',
#  'what movies everyone needs watch least life',
#  'world war ever take place',
#  'how eating prunes help constipation',
#  'given statement correct unccd question cse prelim 2016 many coachings taken 2nd statement wrong',
#  'what would today’s technology never realized value binary numbers harnessed produce digital technology',
#  'what best way invest oil natural gas',
#  'arnab goswami pro-bjp',
#  'what good sources learning nuget',
#  'how would describe person lots interests',
#  'possible turn indicator light dahua camera',
#  'why barack obama important world',
#  'what reason pakistan supports terrorism',
#  'how stop hairfall',
#  'opinion what best classical song time',
#  'what unusual aspects politics government hungary',
#  'what aim',
#  'how respond boss who fired via email',
#  'what cheap budget stay options north goa',
#  'website similar quora',
#  'what conditions european refugee camps',
#  'what opposite homebird',
#  'how know fiance loves',
#  'somebody explain how problem steps',
#  'how develop presence mind',
#  'mathematical fallacies what wrong proof 2+2',
#  'help cibil score pay written-off amount',
#  'hobbit considered canonical tolkien work',
#  'what japanese think malaysian',
#  'har ki dun trek easy',
#  'what good websites learn programming begineer',
#  'supreme court decision playing national anthem movie screenings affect patriotism',
#  'united states female president husband called first gentleman what bill clinton called hillary elected',
#  'how get mooc/e-learning online web video courses related filmmaking production developed indian professors',
#  'mobile number portability finally start may network providers really agree',
#  'why people hate twilight saga',
#  'believe imperialism left positive negative legacy indian subcontinent africa',
#  'why best programming language',
#  'how improve spoken english ability',
#  'how gay sex',
#  'transferring school us curriculum taking ibdp philippine school percent average grading system how get gpa',
#  'how make money youtube',
#  'how find love life',
#  'which option better reduce weight swimming gym',
#  'way get rid gynecomastia',
#  'which payment gateway saudi using collect pay money from/to multiple',
#  'scientific reasons behind hindu temples',
#  'male circumcision required islam',
#  'where get super high quality photos photo booth services sydney',
#  'how find sent friend request instagram',
#  'how control anger',
#  'what genders',
#  'how get quora',
#  'how long raw cooked sausage last refrigerated',
#  'what best available smartphones gadgets',
#  'how feel closeted gay india',
#  'switch roles amazon',
#  'what happens dictatorship continuing present days',
#  'what makes great cup coffee great',
#  'us election rigged',
#  "why n't gayle laakmann mcdowell/careercup created mooc coding bootcamp",
#  'what fermentation what products fermentation',
#  'what think short film colorshift',
#  'war between india pakistan kashmir',
#  'what best way get food stamp card',
#  'what real world example encapsulation abstraction how different yet related',
#  'what ways deal fabricate security insurance android application',
#  'what best accordion beginners learn',
#  'role junior leaders indian army',
#  'what opinion decision removal 500 1000 rupees currency notes',
#  'what mind-blowing facts bengaluru',
#  'parents blood group child',
#  'which book best neet chemistry',
#  'what essence enlightenment',
#  'why many questions posted quora easily answered using google',
#  'how answer interviewer asks sell pen product pursuing mba',
#  'what great side dishes minestrone soup',
#  'how much maximum gold take when flying india usa',
#  'reservation status rac mean seat confirmed',
#  'how new website protect design user interface copycats',
#  'how improve skills',
#  'possible use spi between avr raspberry pi',
#  'which best movies 2016',
#  'what would effect 500 1000 rs notes ban',
#  'what best photos',
#  'why students run away home',
#  'what access modifiers',
#  'analyze history unscientific',
#  'what interesting theories life death',
#  'need get tetanus shot',
#  'how light bend gravity',
#  'what mean hike skirt',
#  'how many new cars sold maserati us year',
#  'how send private message someone following quora',
#  'how train white pitbull brown spots',
#  'what difference between turkey chicken',
#  'what surreal questions asked quora',
#  'what difference between computer science engineering',
#  'when best time sex',
#  'how consult good free online astrologer',
#  "why n't feel sympathy towards everyone",
#  'why brothers hate sisters',
#  'what best site downloading kannada films torrent form',
#  'what gruesome causes death',
#  'what latency telecom',
#  'senior residency hindu rao hospital teaching experience',
#  'what behavioral adaptations pandas',
#  'textile engineering good',
#  'what fastest production car',
#  'how magnets made',
#  'what street value a332',
#  'what qualifications fbi cia agent',
#  'what best operating system pc 2014',
#  'why major indian tv channels absent northeast',
#  'hypothetical scenario actual credit card system banking never existed how would implement digital currency internet today',
#  'how quora quickly mark questions needing improvement',
#  'how contact good hacker',
#  'what best horror novel 2016',
#  'what beautiful thing ever seen',
#  'what important things living good life',
#  'what meaning purpose life',
#  'what when friends betray',
#  '15 year old height feet inches weight 50 kg what gain weight',
#  'why saltwater taffy candy imported china',
#  'different price internet person when trying book room mexico city us',
#  'why venuetastic fail',
#  'which amazing responses got cortana siri amazon echo',
#  'what important life money values',
#  'who best hackers india',
#  'indian education system changed',
#  'what multiple uses hollow columns',
#  'which commonly mispronounced words',
#  'why every teen girl crush mathematics teacher intelligence behavior',
#  'late go medical school become doctor',
#  'where buy best quality commercial innerspring sofa bed chatswood west',
#  'screenshot someone instagram video get notified screenshotted',
#  'what government exams gate final year computer science students give',
#  'what sentences use 26 letters without repeats',
#  'what effect hypodensity white matter parietal lobe brain',
#  'what job salary satisfied current job',
#  'psychopaths find babies cute',
#  'what opera song choir used horror movies',
#  'would woman catholic church shunned ostracized sexual relationship priest',
#  'canadian gets tattoo america declare cost when returning canada',
#  'how see who blocked facebook',
#  'why scarcity high quality fantasy films',
#  'who great coders tamil nadu',
#  'what think when hear word elect',
#  'which best programming language learn 2017',
#  'what ultimate way serve humanity',
#  'how calculate 72 hours',
#  'how hard jimmy wales immigrate uk',
#  'cochin london etihad change time 1hr sufficient dubai',
#  'what quora algorithm sorting answers single question',
#  'what resolution one year 2016',
#  'what balaji viswanathan views caste based reservations india',
#  'jawed habib haircut prices',
#  'one ebook answers wren martin grammer composition',
#  'what math math math x+\\left dfrac right math',
#  'whenever “her” special feeling tried hard forget alwys spcl stop talking even friend',
#  'what mutual funds how work',
#  'how vertebral column anatomy changed time',
#  'which acoustic bass guitar best',
#  'which universities us offer management content management information systems curriculum',
#  'maths become extremely weak class 12th how improve maths clear jee exams next year',
#  'what function context functional programming',
#  'what main difference between socialism communism',
#  'how change facebook password',
#  'how word valiant used sentence',
#  'why feel dizzy when playing 3d games others make feel like tricks developing 3d games avoid',
#  'how payroll companies make money',
#  'what underrated overrated movies seen',
#  'what use cases think deep learning neural networks overkill simpler models work better practice',
#  'which one learn',
#  'fitbit accurately track activity riding bike',
#  'what best evidence historical jesus',
#  'which free online language classes would allow go fluent portuguese given provided courses study',
#  'how pm prez get women',
#  'what best part-time jobs where work home make good cash',
#  'trump chance winning presidency',
#  'what shift job e-commerce cloud computing',
#  'how meet suresh raina',
#  'what name song which picturized madhuri dixit ranbir kapoor which movie',
#  'what function nucleoplasm plant cell',
#  'fossil records used evidence evolution how',
#  'what hizmet movement',
#  'could cat exam mat exam take place day 4th december 2016',
#  'what mythical creatures bible',
#  'which one good oral anal vaginal sex',
#  'what winter weather conditions like cincinnati oh',
#  'what stocks best invest right',
#  'how improve reading skills children',
#  'what someone posted porn video name',
#  'lose nutrients calories when diarrhea',
#  'what safety precautions handling shotguns proposed nra alaska',
#  'what benefit going walking every morning',
#  'martial artists who started later life went become champions',
#  'how get ex back',
#  'which framework choose cross-platform mobile development',
#  'what best way prepare ielts',
#  'how know girl dating online truly live real',
#  'what area games programming mathematically involved suited math major',
#  'what differences between larceny robbery',
#  'graph theory counted prerequisite machine learning',
#  'what best schools study natural language processing india',
#  'ted cruz supporters vote donald trump',
#  'what gdp',
#  'blind trust provision american presidents how enforced',
#  'how make girl who newly joined junior college fall love',
#  'what home remedies piles anal fissure',
#  'how many words actually needed learn gre what correct method prepare gre verbal',
#  'soul immortal',
#  'what personal moon 3rd house stories experiences',
#  'what done reduce pollution india',
#  'government liasioning legal india',
#  'what meaning got ta take shit',
#  'what best place celebrate new year 2017 hyderabad',
#  'what working hard terms studying',
#  'upgrade windows 32 bit 64 bit windows 8.1',
#  'which bad experiences life',
#  'why timbaland famous',
#  'get list individual telephone numbers',
#  'wake rem sleep remember dreams',
#  'what common required elective courses agriculture',
#  'how learn how sing',
#  'who capable ending google monopoly search',
#  'auto immune disease cause insomnia',
#  'gta iv work windows',
#  'which best ssc banking training insititute chandigarh',
#  'which best pmp certification course provider bangalore',
#  'what difference between net gross income',
#  'how wake early morning',
#  'why love',
#  'missed iit what',
#  'what difference between iphone 6s iphone 6s plus',
#  'how one improve credit score 100 points',
#  'crush likes back what',
#  'who powerful character skyrim apart alduin',
#  'muslim guy date non muslim girl based how religious individual factors',
#  'what comments picture',
#  'when roads slippery rain',
#  'how prove heisenberg uncertainty principle experimentally',
#  'what ielts',
#  'how lose weight without sport',
#  'why digital cameras shutter sound',
#  'what like dating gangster',
#  'what main important political causes world war',
#  'how get fear everything',
#  'which city india best weather',
#  'what difference between hdd ssd layman terms',
#  'what mean dog vomits white foam',
#  'life hold significance world/universe',
#  'how job situation new zealand computer science graduates',
#  'how would develop e-commerce website',
#  'how get micro sim card iphone',
#  'what improve question quora',
#  'one people catches feelings established friends benefits arrangement how drop feelings going forward',
#  'what tips someone trying teach sing',
#  'climate change scientists right why worry much public relations packaging',
#  'what main reason problems india',
#  'what good substitute milk macaroni cheese',
#  'how constipation cause dizziness',
#  'possible make doctor review app using which patients share anonymously treatment given doctor suggested medicines',
#  'what pros cons hillary clinton presidency',
#  'what best films take place one room',
#  "normal sperm n't shoot ejaculation",
#  'which best coaching center ssc banking chandigarh',
#  'what next number series 1,1,1,2,2,2,6,6,6',
#  'what best things halloween',
#  'wish start investing equity mutual funds where open demat account best rates transaction charges nri',
#  'why companies issue bonus shares',
#  'how changing 500 1000 rupee notes end black money india',
#  "what major college wo n't leave unemployed engineering law medicine",
#  'who best custom kiosk manufacturers india',
#  'telescopes powerful enough view evidence left behind nasa moon landings',
#  'architectural complex/center/forum/hub anywhere world third space',
#  'how many keywords autohotkey scripting programming language latest version',
#  'what hardest thing raising children ukraine',
#  'what best source learn stock market online',
#  'why india sabotage badmouth economic projects which neighbouring counries world',
#  'what wet vagina feel like man',
#  'thursday night football increase ratings cbs thursday nights rather big bang theory',
#  'how grow taller 17',
#  'ever fired',
#  'how earth would dress like workout guy year 1990 summer',
#  'girlfriend stopped talking what',
#  'what real estate look like 500 1000 scraping',
#  'what best interview questions ever asked',
#  'trust people quickly result always betrayed what trust people still hold relation simple',
#  'who best headhunters mumbai',
#  'what dhp vaccine dogs necessary',
#  'what differences between asia africa what similarities',
#  'wizard magic scientifically tested',
#  'why contract law important',
#  'when moto g3 moto 3rd gen 2015 get android 7.0 nougat update',
#  'prove snr power snr voltage sequare',
#  'what best riddles riddler batman',
#  'why much nudity content game thrones',
#  'how get followers comments blog',
#  'months ca cpt exams how prepare',
#  'what programming language learn want 2d mmorpg game',
#  'what view recent demonetization india',
#  'why cyrus mistry removed',
#  'how cancel usaa auto insurance',
#  'why angry lately',
#  "how form hypothesis since n't done testing n't test results yet",
#  'what consequences trolling',
#  'frightened arvind kejriwal may kill what shall',
#  'what disadvantages apple computers/laptops brands',
#  'what first moment remember life',
#  'what completing bds',
#  'muslims hate narendra modi',
#  '18 what',
#  'what really good famous romantic comedy movies',
#  'how realistic get second bachelors degree math international student holding first bachelors degree accounnting',
#  'how possible believe old testament which one god time believe trinity',
#  'how start meditating',
#  'infinite amount dark vacuum gravitational energy created expansion',
#  'bihar really developing mahagathbandhan sarkar',
#  'how homeopathic medicine side-effects',
#  'how determine what good investment brokerage what',
#  'what scope supply chain management india',
#  'number pistons equal number number cylinders',
#  'post picture social media',
#  'control actions dream',
#  'how managed long distance relationship',
#  'what chances could ask rich person million dollars actually give',
#  'what happened hong kong movies tv drama why decline much',
#  'trump win election',
#  'what best wallpaper apps iphones',
#  'how deactivate app app lock',
#  'what format send book printing',
#  'why caste system still exist india',
#  'how get boyfriend age 13',
#  'what rank 550 marks neet 2016',
#  'dynamic/flexi-pricing harsh middle class people',
#  'overdraft wells fargo account',
#  'what new marketing techniques language schools',
#  'how much olympic gold medalists earn',
#  'what easy ways earn money online',
#  'what reactance capacitor',
#  'true cost living sv bay area high new grads making 150k hard time finding affordable housing',
#  'what best school world',
#  'why saltwater taffy candy imported australia',
#  'what value',
#  'which best part-time jobs bangalore',
#  'how become attractive girl',
#  'what best music albums ever',
#  'realistically speaking what would happen usa donald trump wins presidency 2016 elections',
#  'what symptoms autism kids',
#  'what like non-smoking mother smoking children',
#  'what life without dreams',
#  'how comfortably live washington dc 80,000 salary',
#  'how find girl boyfriend',
#  'what health benefits red lentils',
#  'what math related working models class 10th',
#  'how could gain weight healthy way',
#  'what kind animal',
#  'how anil ambani benefit rafel fighter jet deal',
#  'youtube red offline feature good downloading video',
#  'how know spouse soulmate',
#  'how get people person',
#  'how long distance relationship work',
#  'how speak fluent english',
#  'considering position secretary state gave insight us drone program what reform targeting process',
#  'what exactly mike2.0 layman terms',
#  "why n't buffalo like evolve band together lions cheetahs instead run away",
#  'where find hacker good cause',
#  'how change snapdeal account mobile number',
#  'what tips making job interview process bank',
#  'what main imports exports venezuela how venezuela industry compare cuba',
#  'how lucifer gabrielle relate',
#  'what good movies watch',
#  'how install cydia without jailbreak ios 9.3.5',
#  'what get job microsoft',
#  'why fahrenheit 451 perceived dystopia',
#  'what review love thoughts 2004 movie',
#  'physically possible travel back time',
#  'why awkward people others',
#  'how recover deleted messages facebook',
#  'how compensation system uber',
#  'feasible flipkart offer emi debit cards what different factors involved',
#  'how define tasks vs milestones vs deliverables agile scrum methodology',
#  'life boring what',
#  'where buy meldonium canada',
#  'what would cool way commit suicide',
#  'accidentally took blood pressure medicine twice ok',
#  'paranormal experience',
#  'which 2g band 900/1800mhz sold 2g spectrum scam',
#  'straight student motivation whatsoever go school someone help fight',
#  'which best shares purchase sale daily trading',
#  'girlfriends private partstouched other.can become pregenant',
#  'could use cherenkov atmosphere radiation gamma rays similar image surface planet ground based telescopes',
#  'what good song lyric prank',
#  ...]

# %%
data_train2.question1[105779:105782]
# Out:
# 105779     Which is the most motivational video on YouTube?
# 105781            What are the best short films on YouTube?
# 105782    Division by Zero: If 1/1 equals 1, 2/2 equals ...
# Name: question1, dtype: object

# %%
#db_clear_q1_NS=Text_Cleaning_Utilities.df_to_list_of_texts(data_train2,'question1')

# %%
db_clear_q2=Text_Cleaning_Utilities.df_to_list_of_texts(data_train,'question2',remove_stopwords=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b14e64a93cb9> in <module>()
# ----> 1 db_clear_q2=Text_Cleaning_Utilities.df_to_list_of_texts(data_train,'question2',remove_stopwords=True)
#
# <ipython-input-10-cb34e2a11c18> in df_to_list_of_texts(dataframe, column, remove_stopwords, remove_non_letters, steeming)
#      33                                                                                  remove_stopwords=remove_stopwords,
#      34                                                                                  remove_non_letters=remove_non_letters,
# ---> 35                                                                                  steeming=steeming)))
#      36
#      37         return clean_texts
#
# <ipython-input-10-cb34e2a11c18> in text_to_wordlist(text, remove_stopwords, remove_non_letters, steeming)
#       9         '''Split a text into a list of words'''
#      10         #text = text.replace('-\n','')
# ---> 11         text = text.lower()
#      12         if remove_non_letters:
#      13             text = re.sub("[^-A-Za-z0-9_]", " ", text)
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
#db_clear_q2_NS=Text_Cleaning_Utilities.df_to_list_of_texts(data_train,'question2',remove_stopwords=False)

# %%
# Editing questions with NLTK package

def remove_stopwords(phrase,list_stopwords):
    """
    Receives a phrase and removes all stopwords from a list
    :param phrase: String. A phrase.
    :param list_stopwords: List. A list of stopwords
    :return: The same phrase without stopwords
    """
    final_phrase = []
    words = phrase.split(" ")
    for word in words:
        if word not in list_stopwords:
            final_phrase.append((word))
    
    final_phrase = ' '.join(final_phrase)
    
    return final_phrase
    
def remove_punctuation(phrase):
    """
    Receives a phrase and removes all punctuation from it
    :param phrase: String. A phrase.
    :return: The same phrase without punctuation
    """
    #Check if NA
    if type(phrase) is float:
        if math.isnan(phrase):
            return ("")
    
    translator = str.maketrans('', '', string.punctuation)
    phrase = phrase.translate(translator) #removing punctuation
        
    return phrase

def lemm_wordnet(phrase):
    """
    Receives a phrase and removes lemmatizes it
    :param phrase: String. A phrase.
    :return: The same phrase in lemmas
    """
    lemm = WordNetLemmatizer()
    
    #NA is a float type, so this if is to avoid conflict
    if type(phrase) is not float:
        phrase = [lemm.lemmatize(i) for i in phrase.split()]
        phrase = ' '.join(phrase)
    else:
        return ""
    return phrase
    
def remove_duplicate(phrase):
    """
    Receives a phrase and removes all duplicate words
    :param phrase: String. A phrase.
    :return: The same phrase with just unique words
    """
    aux_phrase = []
        
    if type(phrase) is not float:
        
        for i in phrase.split():
            
            if i not in aux_phrase:
                aux_phrase.append(i)
    
    phrase = ' '.join(aux_phrase)
    
    return phrase
    
    
def all_lower_case(phrase):    
    """
    Receives a phrase and makes it lower case
    :param phrase: String. A phrase.
    :return: The same phrase in lower case
    """
    if type(phrase) is not float:
            phrase = phrase.lower()
    return phrase
    
def stem_snowball(phrase):
    """
    Receives a phrase and returns the same phrase stemmed, lowercase phrase without stopwords
    :param phrase: String. A phrase.
    :return: String. Stemmed, lowercase phrase without stopwords
    """
    stemmer = SnowballStemmer("english")
    
    #Stem words according to stemmer
    final_phrase = []
    words = phrase.split(" ")
    for word in words:
        final_phrase.append((stemmer.stem(word)))
    
    final_phrase = ' '.join(final_phrase)
    
    return final_phrase

stem_snowball("What is the step by step guide to invest in share market in india?")

#This function will return a Bag of words of our two questions using TF method
def vectorizer_tf(data, features = 5000):
    """
    Receives the data frame. Merges all words in question1 and question2 and vectorizes with tf algorithm.
    :param phrase: data frame.
    :param features: number of features for the vectorizes.
    :return: An array with #number of features
    """
    vectorizer_count = CountVectorizer(ngram_range=(1, 2), max_features = features)
    
    merge = data.question1.append([data.question2])
    
    vector_fitt = vectorizer_count.fit(merge)9
    
    question1 = vector_fitt.transform(data.question1)
    question2 = vector_fitt.transform(data.question2)
    
    question1 = question1.toarray()
    question2 = question2.toarray()
    
    return (question1 + question2)/2


#This function will return a Bag of words of our two questions using TF-idf method

def vectorizer_tf_idf(data, features = 5000):
    """
    Receives the data frame. Merges all words in question1 and question2 and vectorizes with tf-idf algorithm.
    :param data: data frame.
    :param features: number of features for the vectorizes.
    :return: An array with #number of features
    """
    vectorizer_tf_idf = TfidfVectorizer(ngram_range=(1, 2), max_features = features, sublinear_tf=True)
    
    merge = data.question1.append([data.question2])
    
    vector_tf_idf_fitt = vectorizer_tf_idf.fit(merge)
    
    question1 = vector_tf_idf_fitt.transform(data.question1)
    question2 = vector_tf_idf_fitt.transform(data.question2)
        
    question1 = question1.toarray()
    question2 = question2.toarray()
    
    return (question1 + question2)/2

# %%
#cleaning tool is used so you can easily choose which functions you want to use to clean te text
def cleaning_tool(data, drop_na = True, lower_case = True, rm_duplicate = False, stopwords = False, 
                  punctuation = False, lemm = False, stem = False, list_of_stopwords = None):
    """
    Function to process all data using calling functions from above, according to what was chosen.
    :param data: data frame.
    :param drop_na: If True drop all lines of data frame with NA
    :param lower_case: If True transform for lower case
    :param rm_duplicate: If True remove all duplicate words in questions
    :param stopwords: If True removes stopwords
    :param punctuation: If True removes punctuation
    :param lemm: If True returns the phrase lemmatized
    :param stem: If True returns the phrase stemmed
    :param list_of_stopwords: List of stopwords to be used
    :return: Question1 and Question2 processed according to parameters
    """
    if drop_na == True:
        data = data.dropna(0)
    
    if rm_duplicate == True:
        data["question1"] = data["question1"].apply(lambda x: remove_duplicate(x))
        data["question2"] = data["question2"].apply(lambda x: remove_duplicate(x))
    
    if lower_case == True:
        data["question1"] = data["question1"].apply(lambda x: all_lower_case(x))
        data["question2"] = data["question2"].apply(lambda x: all_lower_case(x))
    
    if stopwords == True:
        data["question1"] = data["question1"].apply(lambda x: remove_stopwords(x, list_of_stopwords))
        data["question2"] = data["question2"].apply(lambda x: remove_stopwords(x, list_of_stopwords))
       
    if punctuation == True:
        data["question1"] = data["question1"].apply(lambda x: remove_punctuation(x))
        data["question2"] = data["question2"].apply(lambda x: remove_punctuation(x))
        
    if lemm_wordnet == True:
        data["question1"] = data["question1"].apply(lambda x: lemm_wordnet(x))
        data["question2"] = data["question2"].apply(lambda x: lemm_wordnet(x))
        
    if stem_snowball == True:
        data["question1"] = data["question1"].apply(lambda x: stem_snowball(x))
        data["question2"] = data["question2"].apply(lambda x: stem_snowball(x))
    
    #We used it two times if some function create a new NA.
    if drop_na == True:
        data = data.dropna(0)    
        
    return data

# %%
data_train_clean = cleaning_tool(data_train2, stopwords=True, stem=True,list_of_stopwords=mystopwords)

# %%
data_train.info()

# %%
# Perguntar entre o split e word_tokenize
#Verificar http://www.nltk.org/api/nltk.stem.html LEMATIZAR

# %%
# The function "text_to_wordlist" is from
# https://www.kaggle.com/currie32/quora-question-pairs/the-importance-of-cleaning-text
def text_to_wordlist(text, remove_stopwords=False, stem_words=False,wnl_lemmatize=False):
    # Clean the text, with the option to remove stopwords and to stem words.
    
    # Convert words to lower case and split them
    #text = text.lower().split()
    text = text.lower()
    text = word_tokenize(text)
    # Optionally, remove stop words
    if remove_stopwords:
        stops = set(mystopwords)
        text = [w for w in text if not w in stops]
    
    text = " ".join(text)

    # Clean the text
    text = re.sub(r"[^A-Za-z0-9^,!.\/'+-=]", " ", text)#REMOVE NON LETTER
    text = re.sub(r"what's", "what is ", text)
    #text = re.sub(r"\'s", " ", text)# it's , it is or it has
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r",", " ", text)
    text = re.sub(r"\.", " ", text)
    text = re.sub(r"!", " ! ", text)
    text = re.sub(r"\/", " ", text)
    text = re.sub(r"\^", " ^ ", text)
    text = re.sub(r"\+", " + ", text)
    text = re.sub(r"\-", " - ", text)
    text = re.sub(r"\=", " = ", text)
    text = re.sub(r"'", " ", text)
    text = re.sub(r"(\d+)(k)", r"\g<1>000", text)
    text = re.sub(r":", " : ", text)
    text = re.sub(r" e g ", " eg ", text)
    text = re.sub(r" b g ", " bg ", text)
    text = re.sub(r" u s ", " american ", text)
    text = re.sub(r"\0s", "0", text)
    text = re.sub(r" 9 11 ", "911", text)
    text = re.sub(r"e - mail", "email", text)
    text = re.sub(r"j k", "jk", text)
    text = re.sub(r"\s{2,}", " ", text)
    
    # Optionally, shorten words to their stems
    if stem_words:
        text = text.split()
        stemmer = SnowballStemmer('english')
        stemmed_words = [stemmer.stem(word) for word in text]
        text = " ".join(stemmed_words)
      
    # Return a list of words
    return(text)

# %%
# Initialize the "CountVectorizer" object, which is scikit-learn's bag of words tool.
#http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html
vectorizer_tf = CountVectorizer(input='content', 
                               encoding='utf-8', 
                               decode_error='strict', 
                               strip_accents=None, 
                               lowercase=True, 
                               preprocessor=None, 
                               tokenizer=None, 
                               stop_words=mystopwords, 
                               #token_pattern='(?u)\b\w\w+\b',
                               ngram_range=(1, 2),
                               analyzer='word', 
                               max_df=1.0, 
                               min_df=1, 
                               max_features=5000, 
                               vocabulary=None, 
                               binary=False, 
                               dtype=np.int64,
                               )

# %%
#http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
#Another approach using TfIDf vectorizer and using the texts with stopwords in:
#https://github.com/zygmuntz/classifying-text/blob/master/bow_predict.py 
vectorizer_tfidf = TfidfVectorizer(input='content',
                                  #encoding='utf-8',
                                  decode_error='strict',
                                  strip_accents=None,
                                  lowercase=True,
                                  preprocessor=None,
                                  tokenizer=None,
                                  analyzer='word',
                                  stop_words=mystopwords,
                                  #token_pattern='(?u)\b\w\w+\b',
                                  ngram_range=(1, 2),
                                  max_df=1.0,
                                  min_df=1,
                                  max_features=5000,
                                  vocabulary=None, 
                                  binary=False, 
                                  dtype=np.int64,
                                  norm='l2',
                                  use_idf=True,
                                  smooth_idf=True,
                                  sublinear_tf=True)

# %%
data_train_clean_tf = vectorizer_tf.fit_transform(data_train_clean)
data_train_clean_tf = data_train_clean_tf.toarray() # Numpy arrays are easy to work with
print(data_train_clean_tf.shape)

# %%
data= vectorizer_tfidf.fit_transform(data_train_clean)

# %%
  print(data)
